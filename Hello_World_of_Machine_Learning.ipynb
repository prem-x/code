# %% [markdown]
# <a href="https://colab.research.google.com/github/prem-x/code/blob/main/Hello_World_of_Machine_Learning.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import tensorflow as tf
import numpy as np
from tensorflow import keras

# %%
model = tf.keras.Sequential([keras.layers.Dense(units=1, input_shape=[1])])

# %%
model.compile(optimizer='sgd', loss='mean_squared_error')

# %%
xs = np.array([-1.0, 0.0, 1.0, 2.0, 3.0, 4.0], dtype=float)
ys = np.array([-2.0, 1.0, 4.0, 7.0, 10.0, 13.0], dtype=float)

# %%
model.fit(xs, ys, epochs=500)
# Out:
# Epoch 1/500
# 1/1 [==============================] - 1s 545ms/step - loss: 42.1845
# Epoch 2/500
# 1/1 [==============================] - 0s 14ms/step - loss: 33.1916
# Epoch 3/500
# 1/1 [==============================] - 0s 12ms/step - loss: 26.1163
# Epoch 4/500
# 1/1 [==============================] - 0s 14ms/step - loss: 20.5498
# Epoch 5/500
# 1/1 [==============================] - 0s 15ms/step - loss: 16.1703
# Epoch 6/500
# 1/1 [==============================] - 0s 14ms/step - loss: 12.7246
# Epoch 7/500
# 1/1 [==============================] - 0s 14ms/step - loss: 10.0137
# Epoch 8/500
# 1/1 [==============================] - 0s 12ms/step - loss: 7.8808
# Epoch 9/500
# 1/1 [==============================] - 0s 13ms/step - loss: 6.2027
# Epoch 10/500
# 1/1 [==============================] - 0s 11ms/step - loss: 4.8824
# Epoch 11/500
# 1/1 [==============================] - 0s 10ms/step - loss: 3.8436
# Epoch 12/500
# ...

# %%
print(model.predict([10.0]))
# Out:
# 1/1 [==============================] - 0s 98ms/step
# [[31.002003]]
